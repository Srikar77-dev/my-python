# %%
me=["wakeup", "drinkwater", "exercise", "study", "eat", "practice"]
print(me)
# Out:
# ['wakeup', 'drinkwater', 'exercise', 'study', 'eat', 'practice']

# %%
me=["wakeup", "drinkwater", "exercise", "study", "eat", "practice"]
time=["6:00", "6:30", "7:00", "8:00", "12:00", "18:00"]
print(me)
print(time)
# Out:
# ['wakeup', 'drinkwater', 'exercise', 'study', 'eat', 'practice']
# ['6:00', '6:30', '7:00', '8:00', '12:00', '18:00']

# %%
me=["wakeup", "drinkwater", "exercise", "study", "eat", "practice"]
time=["6:00", "6:30", "7:00", "8:00", "12:00", "18:00"]
me1=me.copy()
print(me.sort())
print(me.index("wakeup"))
print(me.append("sleep"))
print(me.pop())
print(me.insert(2, "meditate"))
print(me.remove("exercise"))
print(me1)
print(me)
print(time)
# Out:
# None
# 5
# None
# sleep
# None
# None
# ['wakeup', 'drinkwater', 'exercise', 'study', 'eat', 'practice']
# ['drinkwater', 'eat', 'meditate', 'practice', 'study', 'wakeup']
# ['6:00', '6:30', '7:00', '8:00', '12:00', '18:00']

# %%
#tuple
coordinates=(10.0, 20.0)
print(coordinates)
# Out:
# (10.0, 20.0)

# %%
#tuple
coordinates=[(10.0, 20.0), (30.0, 40.0), (50.0, 60.0)]
print(coordinates[0])
print(coordinates)
# Out:
# (10.0, 20.0)
# [(10.0, 20.0), (30.0, 40.0), (50.0, 60.0)]

# %%
#functions block of code which is reuseable
def light():
    print("Iam the kira")
print("hello N")    
light()
print("And you are died")
# Out:
# hello N
# Iam the kira
# And you are died

# %%
def Anime(name):
    print("Anime Name:", name)

for i in range(4):
    anime_name = input("Enter the name of anime: ")
    Anime(anime_name )
